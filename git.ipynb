# %%
# %cd /content/drive/MyDrive/Github/PhUnWr_ImgProc
# Out:
# /content/drive/MyDrive/Github/PhUnWr_ImgProc

# %%
# !git init PhUnwr_ImgProc
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Github/PhUnWr_ImgProc/PhUnwr_ImgProc/.git/

# %%
# Out:
# /content/drive/MyDrive/Github/PhUnwr_CNN_ImgProc

# %%
# !ls
# Out:
# createDatabase.py     PhUnwr_CNN	  toDataFrame.py
# extractImg.py	      PhUnwr_CNN_ImgProc  wrapper.py
# gaussTest.py	      PhUnwr_ImgProc	  wrapper_rescale_noise.py
# gauss_test_scikit.py  quickproc.py	  wrapper_rescale.py
# main.py		      toDataBase.py

# %%
# !git checkout

# %%
# !git remote -v 
# !git remote remove origin 
# !git remote add origin https://mgontarz20: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@github.com/mgontarz20/PhUnWr_ImgProc.git
# Out:
# origin	https://mgontarz20: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@github.com/mgontarz20/PhUnWr_ImgProc.git (fetch)
# origin	https://mgontarz20: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@github.com/mgontarz20/PhUnWr_ImgProc.git (push)

# %%
# Out:
# origin	https://mgontarz20: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@github.com/mgontarz20/PhUnwr_CNN.git (fetch)
# origin	https://mgontarz20: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@github.com/mgontarz20/PhUnwr_CNN.git (push)

# %%
# !git config --global user.email "mgontarz20@gmail.com"

# %%
# !git config --global user.name "Michał Gontarz"

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git commit -m "Added network model QPI_DIP_Net."
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git push -f origin master
# Out:
# Counting objects: 13, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 8.75 KiB | 746.00 KiB/s, done.
# Total 13 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/mgontarz20/PhUnWr_ImgProc.git
#  + 9e6ac7c...73414e2 master -> master (forced update)
