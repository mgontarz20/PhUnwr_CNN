# %%
# Out:
# [Errno 2] No such file or directory: 'content/drive/My Drive/'
# /content

# %%
# %cd /content/drive/MyDrive/Github/PhUnwr_CNN
# Out:
# /content/drive/MyDrive/Github/PhUnwr_CNN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Github/PhUnwr_CNN/.git/

# %%
# !git remote add origin https://mgontarz20:DawD2@@2@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git

# %%
# !git remote -v
# Out:
# origin	https://mgontarz20:DawD2@@2@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git (fetch)
# origin	https://mgontarz20:DawD2@@2@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git (push)

# %%
# !git config --global user.email "mgontarz20@gmail.com"

# %%
# !git con
