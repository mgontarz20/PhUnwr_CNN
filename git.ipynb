# %%
# Out:
# [Errno 2] No such file or directory: 'content/drive/My Drive/'
# /content

# %%
# %cd /content/drive/MyDrive/Github/PhUnwr_CNN
# Out:
# /content/drive/MyDrive/Github/PhUnwr_CNN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Github/PhUnwr_CNN/.git/

# %%
# !git remote rm origin
git remote add origin https://github.com/mgontarz20/PhUnwr_CNN.git
# !git remote add origin https://mgontarz20:radioactiv213@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git

# %%
# !git remote -v
# Out:
# origin	https://mgontarz20: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@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git (fetch)
# origin	https://mgontarz20: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@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git (push)

# %%
# !git config --global user.email "mgontarz20@gmail.com"

# %%
# !git config --global user.name "Michał Gontarz"

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   git.ipynb

# %%
# !git add PanelSterowaniaGC.ipynb

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   git.ipynb

# %%
# !git commit -m "First Commit."
# Out:
# [master 8d53217] First Commit.
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (80%)

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git push origin master
# Out:
# remote: Not Found
# fatal: repository 'https://mgontarz20:radioactiv213@github.com/https://github.com/mgontarz20/PhUnwr_CNN.git/' not found
