# %%
# Out:
# [Errno 2] No such file or directory: 'content/drive/My Drive/'
# /content

# %%
# %cd /content/drive/MyDrive/Github/PhUnwr_CNN
# Out:
# /content/drive/MyDrive/Github/PhUnwr_CNN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Github/PhUnwr_CNN/.git/

# %%
# !git remote rm origin
# !git remote add origin https://mgontarz20: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@github.com/mgontarz20/PhUnwr_CNN.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/mgontarz20/PhUnwr_CNN.git (fetch)
# origin	https://github.com/mgontarz20/PhUnwr_CNN.git (push)

# %%
# !git config --global user.email "mgontarz20@gmail.com"

# %%
# !git config --global user.name "Michał Gontarz"

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   git.ipynb

# %%
# !git add PanelSterowaniaGC.ipynb

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   git.ipynb

# %%
# !git commit -m "First Commit."
# Out:
# [master f96f23e] First Commit.
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (74%)

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git push -u origin master
# Out:
# Counting objects: 18, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (18/18), done.
# Writing objects: 100% (18/18), 46.27 KiB | 1.59 MiB/s, done.
# Total 18 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), done.
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/mgontarz20/PhUnwr_CNN/pull/new/master
# remote:
# To https://github.com/mgontarz20/PhUnwr_CNN.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# Out:
#   File "<ipython-input-70-758e6f3ab423>", line 1
#     GET /repos/:owner/:repo
#                ^
# SyntaxError: invalid syntax
